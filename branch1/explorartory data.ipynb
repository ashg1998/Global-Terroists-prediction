# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset=pd.read_excel('terr_data.xlsm')

# %%
data=dataset.copy()

# %%
features=[feature for feature in data.columns if data[feature].isnull().sum()>1]

# %%
for feature in features:
    print(feature, np.round(dataset[feature].isnull().mean(), 4),  ' % missing values')
# Out:
# natlty1_txt 0.013  % missing values
# weapsubtype1_txt 0.104  % missing values
# weapdetail 0.6132  % missing values
# nkill 0.0598  % missing values
# nwound 0.1048  % missing values
# propextent_txt 0.6444  % missing values
# ransomamt 0.9938  % missing values

# %%
numerical_feature=[feature for feature in data.columns if data[feature].dtypes!='O']
len(numerical_feature)
# Out:
# 6

# %%
categorical_feature=[feature for feature in data.columns if data[feature].dtypes=='O']
len(categorical_feature)
# Out:
# 12

# %%
#data[categorical_feature].head()

# %%
len(data['gname'].unique())
# Out:
# 769

# %%
l=data.gname.value_counts(sort=True)

# %%
#x= [name for name in l if data.gname.value_counts >20]

# %%
print(l.sample(n=100))
# Out:
# Hizbul Mujahideen (HM)           71
# Pro-Russia Militia               15
# Caspian Group                     1
# Anti-Government extremists        9
# Lama Group                        1
#                                  ..
# Ansaru ash-Sharia (Russia)        1
# Informal Anarchist Federation    23
# Libya Shield Force                8
# Mujahedeen Army                   1
# Maute Group                      15
# Name: gname, Length: 100, dtype: int64

# %%
l=l.sample(n=100)
plt.subplots(figsize=(20,10))
p=sns.barplot(l.index,l)
p.set_xticklabels(l.index,rotation=90)
plt.show()

# %%
l=data.gname.value_counts()<5

# %%
len(indexes)
# Out:
# 495

# %%
data=dataset.copy()

# %%
type(l)
# Out:
# pandas.core.series.Series

# %%
l_index=l[l==True].index

# %%
data['gname']=np.where(data['gname'].isin(l_index),dataset['gname'],'Rare_var')

# %%
l=data.gname.value_counts(sort=True)
l=l.sample(n=100)
plt.subplots(figsize=(20,10))
p=sns.barplot(l.index,l)
p.set_xticklabels(l.index,rotation=90)
plt.show()

# %%
data.to_xlsx("testing data",index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-fbad88477bf5> in <module>
# ----> 1 data.to_xlsx("testing data",index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'to_xlsx'
